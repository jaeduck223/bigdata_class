# %% [markdown]
# <a href="https://colab.research.google.com/github/jaeduck223/bigdata_class/blob/main/%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EC%84%9D_8%EC%A3%BC%EC%B0%A8_2%EA%B0%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({'key1': ['a', 'a', 'b', 'b', 'a'],
                  'key2': ['one', 'two', 'one', 'two', 'one'],
                  'data1': np.random.randn(5),
                  'data2': np.random.randn(5)})
df
# Out:
#   key1 key2     data1     data2
# 0    a  one  1.077218  0.491334
# 1    a  two  0.231882 -1.106545
# 2    b  one  1.605746  1.049006
# 3    b  two  0.039269  0.385565
# 4    a  one  0.830536 -0.478661

# %%
unique_keys = df['key1'].unique()  # key1의 고유 값 추출
averages = {}

for key in unique_keys:
    # key1 값이 현재 key와 같은 행만 필터링
    filtered_data = df[df['key1'] == key]
    # data1의 평균 계산
    averages[key] = filtered_data['data1'].mean()

print(averages)
# Out:
# {'a': np.float64(0.7132122963147456), 'b': np.float64(0.8225071306934605)}

# %%
tmp = df.set_index(['key1', 'key2'])
tmp
# Out:
#               data1     data2
# key1 key2
# a    one   1.077218  0.491334
#      two   0.231882 -1.106545
# b    one   1.605746  1.049006
#      two   0.039269  0.385565
# a    one   0.830536 -0.478661

# %%
tmp.loc['a'].data1.mean()
# Out:
# np.float64(0.7132122963147456)

# %%
tmp.loc['b'].data1.mean()
# Out:
# np.float64(0.8225071306934605)

# %%
grouped = df['data1'].groupby(df['key1'])  #groubed 변수는 Groupby 객체이다.
grouped
#groubed 변수는 Groupby 객체이다.
#df['key1']에 의해 참조되는 중간값에 대한 것 외에는 아무것도 계산되지 않은 객체이다.
#이 객체는 그룹 연산을 위해 필요한 모든 정보를 가지고 있으며, 각 그룹에 어떤 연산을 적용할 수 있게 해준다.

# %%
grouped.mean() #그룹별 평균을 구하려면 Groupby 객체의 mean 메서드 사용
# 데이터가 그룹색인에 따라 수집된다. 즉, key1 컬럼에 있는 유일한 값으로 색인되는 새로운 Series객체가 생성된다.
# 새로 생성된 객체의 색인은 'key1'인데, 그 이유는 DataFrame 컬럼인 df['key1']이기 때문이다.
# Out:
# key1
# a    0.713212
# b    0.822507
# Name: data1, dtype: float64

# %%
grouped.sum()
# Out:
# key1
# a    2.139637
# b    1.645014
# Name: data1, dtype: float64

# %%
grouped = df['data1'].groupby(df['key1']).mean()  #groubed 변수는 Groupby 객체이다.
grouped
# Out:
# key1
# a    0.713212
# b    0.822507
# Name: data1, dtype: float64

# %%
df.pivot_table(index='key1', values='data1', aggfunc= 'mean')
#pivot table을 이용해 그룹을 지은 다음, 평균을 구함.
# Out:
#          data1
# key1
# a     0.713212
# b     0.822507

# %%
means = df['data1'].groupby([df['key1'], df['key2']]).mean()
means
#데이터를 두개의 색인으로 묶었고, 그 결과 계층적 색인을 가지는 Series 객체를 얻을 수 있다.
# Out:
# key1  key2
# a     one     0.953877
#       two     0.231882
# b     one     1.605746
#       two     0.039269
# Name: data1, dtype: float64

# %%
means = df.groupby([df['key1'], df['key2']]).mean()
means
# Out:
#               data1     data2
# key1 key2
# a    one   0.953877  0.006337
#      two   0.231882 -1.106545
# b    one   1.605746  1.049006
#      two   0.039269  0.385565

# %%
df.pivot_table(index=['key1', 'key2'], values='data1', aggfunc= 'mean')
# Out:
#               data1
# key1 key2
# a    one   0.953877
#      two   0.231882
# b    one   1.605746
#      two   0.039269

# %%
# 이 예제에서는 그룹의 색인 모두 Series 객체이다. 길이만 같다면 어떤 배열이라도 상관 없다.
states = np.array(['Ohio', 'California', 'California', 'Ohio', 'Ohio'])
years = np.array([2005, 2005, 2006, 2005, 2006])
df['data1'].groupby([states, years]).mean()
# Out:
# California  2005    0.231882
#             2006    1.605746
# Ohio        2005    0.558244
#             2006    0.830536
# Name: data1, dtype: float64

# %%
df
# Out:
#   key1 key2     data1     data2
# 0    a  one  1.077218  0.491334
# 1    a  two  0.231882 -1.106545
# 2    b  one  1.605746  1.049006
# 3    b  two  0.039269  0.385565
# 4    a  one  0.830536 -0.478661

# %%
df.groupby('key1').mean(numeric_only = True) #숫자로 된 데이터만 고려하게끔 함.
#key2 컬럼이 결과에서 빠졌다. df['key2']는 숫자 데이터가 아니다. 이런 컬럼은 성가신 컬럼(nuisance column)이라고 하며 결과에서 제외한다.
# Out:
#          data1     data2
# key1
# a     0.713212 -0.364624
# b     0.822507  0.717286

# %%
df.groupby(['key1', 'key2']).mean()
#df.groupby([df['key1'], df['key2']]).mean()
# Out:
#               data1     data2
# key1 key2
# a    one   0.953877  0.006337
#      two   0.231882 -1.106545
# b    one   1.605746  1.049006
#      two   0.039269  0.385565

# %%
df.groupby(['key1', 'key2']).size()
# size 메서드는 그룹의 크기를 담고 있는 Series를 반환한다.
# Out:
# key1  key2
# a     one     2
#       two     1
# b     one     1
#       two     1
# dtype: int64

# %%
df
# Out:
#   key1 key2     data1     data2
# 0    a  one  1.077218  0.491334
# 1    a  two  0.231882 -1.106545
# 2    b  one  1.605746  1.049006
# 3    b  two  0.039269  0.385565
# 4    a  one  0.830536 -0.478661

# %%
for name, group in df.groupby('key1'):
    print(name)
    print(group)
# Out:
# a
#   key1 key2     data1     data2
# 0    a  one  1.077218  0.491334
# 1    a  two  0.231882 -1.106545
# 4    a  one  0.830536 -0.478661
# b
#   key1 key2     data1     data2
# 2    b  one  1.605746  1.049006
# 3    b  two  0.039269  0.385565

# %%
for (k1, k2), group in df.groupby(['key1', 'key2']):  #색인이 여럿 존재하는 경우 튜플의 첫 번째 원소가 색인값이 된다.
    print((k1, k2)) #총 4가지 경우가 출력됨.
    print(group)
# Out:
# ('a', 'one')
#   key1 key2     data1     data2
# 0    a  one  1.077218  0.491334
# 4    a  one  0.830536 -0.478661
# ('a', 'two')
#   key1 key2     data1     data2
# 1    a  two  0.231882 -1.106545
# ('b', 'one')
#   key1 key2     data1     data2
# 2    b  one  1.605746  1.049006
# ('b', 'two')
#   key1 key2     data1     data2
# 3    b  two  0.039269  0.385565

# %%
#df.groupby(['key1', 'key2'])[['data2']].mean() #data2 컬럼에 대한 평균만 구하고 싶을때(출력이 데이터프레임)
df.groupby(['key1', 'key2'])['data2'].mean() #data2 컬럼에 대한 평균만 구하고 싶을때(출력이 시리즈임.)
# Out:
# key1  key2
# a     one     0.006337
#       two    -1.106545
# b     one     1.049006
#       two     0.385565
# Name: data2, dtype: float64

# %%
people = pd.DataFrame(np.random.randn(5,5),
                     columns = ['a', 'b', 'c', 'd', 'e'],
                     index = ['Joe', 'steve', 'Wes', 'Jim', 'Travis'])
people.iloc[2:3, [1,2]] = np.nan # a few NA values

people
# Out:
#                a         b         c         d         e
# Joe     0.306425 -0.671579 -0.017810 -2.211153 -0.704097
# steve   0.004469 -0.226042 -0.378680 -0.647362 -0.516821
# Wes     0.046552       NaN       NaN -0.264379  0.021191
# Jim     1.033572  0.281271 -0.157521 -0.445915  0.636382
# Travis -0.962945  0.879687  0.173980  0.348659 -1.460856

# %%
mapping = {'a': 'red', 'b': 'red', 'c': 'blue',
          'd': 'blue', 'e': 'red', 'f': 'orange'} #더 많아도 정해진 크기만큼만 출력함.

# %%
mapping
# Out:
# {'a': 'red', 'b': 'red', 'c': 'blue', 'd': 'blue', 'e': 'red', 'f': 'orange'}

# %%
by_column = people.groupby(mapping, axis='columns')  #f는 사용되지 않음. 사용하지 않는 그룹 키도 문제 없다는것을 보여주는 예
by_column.sum()
# Out:
# <ipython-input-34-52b1ae7c1ba7>:1: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   by_column = people.groupby(mapping, axis='columns')  #f는 사용되지 않음. 사용하지 않는 그룹 키도 문제 없다는것을 보여주는 예
#             blue       red
# Joe    -2.228963 -1.069250
# steve  -1.026042 -0.738395
# Wes    -0.264379  0.067743
# Jim    -0.603437  1.951225
# Travis  0.522639 -1.544114

# %%
by_column = people.T.groupby(mapping).sum()

# %%
by_column
# Out:
#            Joe     steve       Wes       Jim    Travis
# blue -2.228963 -1.026042 -0.264379 -0.603437  0.522639
# red  -1.069250 -0.738395  0.067743  1.951225 -1.544114

# %%
by_column.T
# Out:
#             blue       red
# Joe    -2.228963 -1.069250
# steve  -1.026042 -0.738395
# Wes    -0.264379  0.067743
# Jim    -0.603437  1.951225
# Travis  0.522639 -1.544114

# %%
map_series = pd.Series(mapping)

map_series
# Out:
# a       red
# b       red
# c      blue
# d      blue
# e       red
# f    orange
# dtype: object

# %%
people.groupby(map_series, axis=1).count()
# Out:
# <ipython-input-41-5250dc3b013c>:1: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   people.groupby(map_series, axis=1).count()
#         blue  red
# Joe        2    3
# steve      2    3
# Wes        1    2
# Jim        2    3
# Travis     2    3

# %%
people.groupby(len).sum() #배열을 넘기는 대신 len 함수를 넘긴 경우
# people은 사람의 이름을 색인값으로 사용하였다. len 함수를 넘기면 이름의 길이별로 그룹을 묶어준다.
#people.groupby(type).sum() #배열을 넘기는 대신 len 함수를 넘긴 경우
# Out:
#           a         b         c         d         e
# 3  1.386549 -0.390308 -0.175331 -2.921447 -0.046524
# 5  0.004469 -0.226042 -0.378680 -0.647362 -0.516821
# 6 -0.962945  0.879687  0.173980  0.348659 -1.460856

# %%
key_list = ['one', 'one', 'one', 'two', 'two']

people.groupby([len, key_list]).min()
#내부적으로 모두 배열로 변환대므로 함수를 배열, 사전, Series와 섞어 쓰더러도 문제가 없다.
# Out:
#               a         b         c         d         e
# 3 one  0.046552 -0.671579 -0.017810 -2.211153 -0.704097
#   two  1.033572  0.281271 -0.157521 -0.445915  0.636382
# 5 one  0.004469 -0.226042 -0.378680 -0.647362 -0.516821
# 6 two -0.962945  0.879687  0.173980  0.348659 -1.460856

# %%
people
# Out:
#                a         b         c         d         e
# Joe     0.306425 -0.671579 -0.017810 -2.211153 -0.704097
# steve   0.004469 -0.226042 -0.378680 -0.647362 -0.516821
# Wes     0.046552       NaN       NaN -0.264379  0.021191
# Jim     1.033572  0.281271 -0.157521 -0.445915  0.636382
# Travis -0.962945  0.879687  0.173980  0.348659 -1.460856

# %%
columns = pd.MultiIndex.from_arrays([['US', 'US', 'US', 'JP', 'JP'],
                                    [1, 3, 5, 1, 3]],
                                   names=['cty', 'tenor'])
hier_df = pd.DataFrame(np.random.randn(4,5), columns=columns)
hier_df
# Out:
# cty          US                            JP
# tenor         1         3         5         1         3
# 0      0.413698  0.195203  0.273009 -1.051544  0.469923
# 1      0.643182  1.011134 -0.202249  1.682849  0.309197
# 2     -0.793125 -0.625718 -1.553439  1.832928  0.253891
# 3     -0.734043 -1.302201  0.935152 -0.237608  2.068875

# %%
hier_df.groupby(level='cty', axis=1).count()
# Out:
# <ipython-input-50-ef7f1879ebcd>:1: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   hier_df.groupby(level='cty', axis=1).count()
# cty  JP  US
# 0     2   3
# 1     2   3
# 2     2   3
# 3     2   3

# %%
hier_df.T.groupby(level='cty').count().T
# Out:
# cty  JP  US
# 0     2   3
# 1     2   3
# 2     2   3
# 3     2   3

# %%
hier_df.groupby(level='tenor', axis=1).count()
# Out:
# <ipython-input-52-2bfb74499ea7>:1: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   hier_df.groupby(level='tenor', axis=1).count()
# tenor  1  3  5
# 0      2  2  1
# 1      2  2  1
# 2      2  2  1
# 3      2  2  1

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({'key1': ['a', 'a', None, 'b', 'b', 'a', None],
                  'key2': pd.Series([1, 2, 1, 2, 1, None, 1], dtype='Int64'),
                  'data1': np.random.standard_normal(7),
                  'data2': np.random.standard_normal(7)})
df
# Out:
#    key1  key2     data1     data2
# 0     a     1 -0.290512 -1.294912
# 1     a     2 -0.529816 -1.303851
# 2  None     1 -0.103368  0.194962
# 3     b     2  0.026784  1.470641
# 4     b     1  0.171436 -0.078888
# 5     a  <NA> -0.739944  0.237955
# 6  None     1  0.647381 -1.878987

# %%
grouped = df.groupby('key1')
grouped['data1'].quantile(0.9)
#quantile() 의 괄호 안에 0~1 사이의 값을 넣어주면 분위수를 계산해주며,
#최소값과 최대값을 등분하여 그 사이를 interpolation 하여 분위수를 계산
# Out:
# key1
# a   -0.338372
# b    0.156971
# Name: data1, dtype: float64

# %%
def peak_to_peak(arr):
    return arr.max() - arr.min()

grouped.agg(peak_to_peak)
# Out:
#       key2     data1     data2
# key1
# a        1  0.449433  1.541806
# b        1  0.144652  1.549529
